# %%
from monai.networks.nets import DiffusionModelUNet
from monai.networks.schedulers import DDPMScheduler

# This creates the architecture for a 2D denoiser
model = DiffusionModelUNet(
    spatial_dims=2,
    in_channels=1,
    out_channels=1,
    num_channels=(128, 256, 256),
    attention_levels=(False, True, True),
    num_res_blocks=2,
)
# Out:
# <frozen importlib._bootstrap_external>:1325: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 from monai.networks.schedulers import DDPMScheduler
#       4 # This creates the architecture for a 2D denoiser
# ----> 5 model = DiffusionModelUNet(
#       6     spatial_dims=2,
#       7     in_channels=1,
#       8     out_channels=1,
#       9     num_channels=(128, 256, 256),
#      10     attention_levels=(False, True, True),
#      11     num_res_blocks=2,
#      12 )
#
# TypeError: DiffusionModelUNet.__init__() got an unexpected keyword argument 'num_channels'. Did you mean 'out_channels'?
